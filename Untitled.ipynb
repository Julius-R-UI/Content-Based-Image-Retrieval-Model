# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import cv2 as cv
from tensorflow import keras
from tensorflow.keras import optimizers
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from keras import layers, Model, optimizers
from PIL import Image,ImageOps
from sklearn.metrics import mean_squared_error
import os
from tensorflow.keras.applications import MobileNetV2
import gc
from sklearn.neighbors import NearestNeighbors
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
filenames = os.listdir('dataset') #.remove('.ipynb_checkpoints')

# %%
filenames.remove('.ipynb_checkpoints')

# %%
x = np.array([np.array(Image.open('./dataset/'+str(i)).convert('RGB')) for i in filenames])

# %%
x = x.astype('float32') / 255.

# %%
x.shape
# Out:
# (4738, 512, 512, 3)

# %%
x_t = x[0:4]

# %%
x_t.shape
# Out:
# (4, 512, 512, 3)

# %%
x = x[4:]

# %%
plt.imshow(x_t[-1])

# %%
plt.imshow(x[0])

# %%
class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
base_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(512,512,3))
base_model.trainable = False
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Metal device set to: Apple M1 Max
# 2022-03-13 21:31:50.265765: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-03-13 21:31:50.265889: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
input_img = layers.Input((512,512,3))
l = layers.Conv2D(8, (3,3), activation = tf.keras.layers.LeakyReLU(0.25), padding = 'same')(input_img)
l = layers.MaxPooling2D((2,2))(l)
l = layers.Conv2D(16, (3,3), activation = tf.keras.layers.LeakyReLU(0.25), padding = 'same')(l)
l = layers.MaxPooling2D((2,2))(l)
l = layers.Conv2D(32, (3,3), activation = tf.keras.layers.LeakyReLU(0.25), padding = 'same')(l)
l = layers.MaxPooling2D((2,2))(l)
l = layers.Conv2D(64, (3,3), activation = tf.keras.layers.LeakyReLU(0.25), padding = 'same')(l)
l = layers.MaxPooling2D((2,2))(l)
l = layers.Conv2D(128, (3,3), activation = tf.keras.layers.LeakyReLU(0.25), padding = 'same')(l)
l = layers.Flatten()(l)
encoded = layers.Dense(128, activation = tf.keras.layers.LeakyReLU(0.25))(l)

l = layers.Dense(32*32*128, activation = tf.keras.layers.LeakyReLU(0.25))(encoded)
l = layers.Reshape((32,32,128))(l)
l = layers.Conv2D(128, (3, 3), activation=tf.keras.layers.LeakyReLU(0.25), padding='same')(l)
l = layers.UpSampling2D((2, 2))(l)
l = layers.Conv2D(64, (3, 3), activation=tf.keras.layers.LeakyReLU(0.25), padding='same')(l)
l = layers.UpSampling2D((2, 2))(l)
l = layers.Conv2D(32, (3, 3), activation=tf.keras.layers.LeakyReLU(0.25), padding='same')(l)
l = layers.UpSampling2D((2, 2))(l)
l = layers.Conv2D(16, (3, 3), activation=tf.keras.layers.LeakyReLU(0.25), padding='same')(l)
l = layers.UpSampling2D((2, 2))(l)
l = layers.Conv2D(8, (3, 3), activation=tf.keras.layers.LeakyReLU(0.25), padding='same')(l)
decoded = layers.Conv2D(3, (3, 3), activation='sigmoid', padding='same', kernel_initializer = tf.keras.initializers.GlorotNormal())(l)

b = base_model(decoded)
auto_encoder = Model(input_img, b)

# %%
auto_encoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 512, 512, 3)]     0
#
#  conv2d (Conv2D)             (None, 512, 512, 8)       224
#
#  max_pooling2d (MaxPooling2D  (None, 256, 256, 8)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 16)      1168
#
#  max_pooling2d_1 (MaxPooling  (None, 128, 128, 16)     0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 32)      4640
#
#  max_pooling2d_2 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 128)       73856
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 128)               16777344
#
#  dense_1 (Dense)             (None, 131072)            16908288
#
#  reshape (Reshape)           (None, 32, 32, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 128)       147584
#
#  up_sampling2d (UpSampling2D  (None, 64, 64, 128)      0
#  )
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 64)        73792
#
#  up_sampling2d_1 (UpSampling  (None, 128, 128, 64)     0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 128, 128, 32)      18464
#
#  up_sampling2d_2 (UpSampling  (None, 256, 256, 32)     0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 256, 256, 16)      4624
#
#  up_sampling2d_3 (UpSampling  (None, 512, 512, 16)     0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 512, 512, 8)       1160
#
#  conv2d_10 (Conv2D)          (None, 512, 512, 3)       219
#
#  mobilenetv2_1.00_224 (Funct  (None, 16, 16, 1280)     2257984
#  ional)
#
# =================================================================
# Total params: 36,287,843
# Trainable params: 34,029,859
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
auto_encoder.compile(optimizer=tf.optimizers.Adam(1e-4), loss='mse')

# %%
model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(512,512,3))
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
'''y_ = []
for i in range(len(x)):
    y_.append(model.predict(x[i].reshape((1,512,512,3))).tolist())
np.save('MobileNetV2_pred.npy', np.array(y_))
'''
# Out:
# "y_ = []\nfor i in range(len(x)):\n    y_.append(model.predict(x[i].reshape((1,512,512,3))).tolist())\nnp.save('MobileNetV2_pred.npy', np.array(y_))\n"

# %%
with open('MobileNetV2_pred.npy', 'rb') as f:
    y_ = np.load(f)

# %%
y_.shape
# Out:
# (4734, 1, 16, 16, 1280)

# %%
x.shape
# Out:
# (4734, 512, 512, 3)

# %%
class CustomCallback(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        plt.imshow(Model(auto_encoder.input,auto_encoder.layers[-2].output).predict(x[0].reshape((1,512,512,3))).reshape((512,512,3)))
        plt.savefig('Epoch_images/'+str(epoch)+'.png')

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 2)

# %%
with tf.device('/device:GPU:0'):
    auto_encoder.fit(x,y_, epochs=25, validation_split=0.01, callbacks=[CustomCallback()])
# Out:
# 2022-03-13 21:32:07.222424: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 1/25
# 2022-03-13 21:32:07.885514: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - ETA: 0s - loss: 0.5696
# 2022-03-13 21:38:25.008160: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 379s 3s/step - loss: 0.5696 - val_loss: 0.5963
# 2022-03-13 21:38:26.218664: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 2/25
# 147/147 [==============================] - 373s 3s/step - loss: 0.1796 - val_loss: 0.5882
# 2022-03-13 21:44:39.085950: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 3/25
# 147/147 [==============================] - 1539s 11s/step - loss: 0.1741 - val_loss: 0.5866
# 2022-03-13 22:10:18.383902: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# Epoch 4/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1726
# 2022-03-13 22:18:22.860484: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 485s 3s/step - loss: 0.1726 - val_loss: 0.5856
# Epoch 5/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1720WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x29fd39700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2022-03-13 22:31:48.200707: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 805s 5s/step - loss: 0.1720 - val_loss: 0.5855
# Epoch 6/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1717
# 2022-03-13 22:45:47.095097: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2ce735550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 147/147 [==============================] - 839s 6s/step - loss: 0.1717 - val_loss: 0.5848
# Epoch 7/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1715
# 2022-03-13 22:59:35.196059: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 828s 6s/step - loss: 0.1715 - val_loss: 0.5843
# Epoch 8/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1714
# 2022-03-13 23:13:14.816534: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 820s 6s/step - loss: 0.1714 - val_loss: 0.5847
# Epoch 9/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1714
# 2022-03-13 23:27:25.641289: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 851s 6s/step - loss: 0.1714 - val_loss: 0.5841
# Epoch 10/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1713
# 2022-03-13 23:41:10.880598: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 825s 6s/step - loss: 0.1713 - val_loss: 0.5841
# Epoch 11/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1713
# 2022-03-13 23:52:51.755676: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 700s 5s/step - loss: 0.1713 - val_loss: 0.5835
# Epoch 12/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1712
# 2022-03-13 23:59:08.240662: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 376s 3s/step - loss: 0.1712 - val_loss: 0.5831
# Epoch 13/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1712
# 2022-03-14 00:05:24.161664: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 376s 3s/step - loss: 0.1712 - val_loss: 0.5835
# Epoch 14/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1712
# 2022-03-14 00:11:38.560774: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 374s 3s/step - loss: 0.1712 - val_loss: 0.5838
# Epoch 15/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1712
# 2022-03-14 00:17:48.436914: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 370s 3s/step - loss: 0.1712 - val_loss: 0.5828
# Epoch 16/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1712
# 2022-03-14 00:23:56.148597: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 368s 2s/step - loss: 0.1712 - val_loss: 0.5829
# Epoch 17/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1711
# 2022-03-14 00:53:19.117941: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 1763s 12s/step - loss: 0.1711 - val_loss: 0.5845
# Epoch 18/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1711
# 2022-03-14 01:13:21.946809: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 1203s 8s/step - loss: 0.1711 - val_loss: 0.5831
# Epoch 19/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1711
# 2022-03-14 01:25:51.656738: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 750s 5s/step - loss: 0.1711 - val_loss: 0.5831
# Epoch 20/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1711
# 2022-03-14 01:39:15.243056: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 804s 5s/step - loss: 0.1711 - val_loss: 0.5829
# Epoch 21/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1711
# 2022-03-14 01:52:34.150076: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 799s 5s/step - loss: 0.1711 - val_loss: 0.5828
# Epoch 22/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1711
# 2022-03-14 02:05:58.558250: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 804s 5s/step - loss: 0.1711 - val_loss: 0.5838
# Epoch 23/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1710
# 2022-03-14 02:19:20.414868: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 802s 5s/step - loss: 0.1710 - val_loss: 0.5834
# Epoch 24/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1710
# 2022-03-14 02:44:24.528886: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 1504s 10s/step - loss: 0.1710 - val_loss: 0.5821
# Epoch 25/25
# 147/147 [==============================] - ETA: 0s - loss: 0.1710
# 2022-03-14 03:08:26.749933: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 147/147 [==============================] - 1442s 10s/step - loss: 0.1710 - val_loss: 0.5827

# %%
f1 = auto_encoder.predict(x_t[0].reshape((1,512,512,3)))
# Out:
# 2022-03-14 03:08:27.813567: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
f2 = auto_encoder.predict(x_t[1].reshape((1,512,512,3)))

# %%
np.array_equal(f1,f2)
# Out:
# False

# %%
np.array_equal(np.ones(f1.shape),f1)
# Out:
# False

# %%
np.array_equal(np.ones(f2.shape),f2)
# Out:
# False

# %%
np.array_equal(np.ones(f2.shape),f2)
# Out:
# False

# %%
def display(x, chosen_locations):
    plt.figure(figsize=(10,10)) # specifying the overall grid size

    for i in range(len(chosen_locations[0])):
        plt.subplot(5,5,i+1)    # the number of images in the grid is 5*5 (25)
        plt.imshow(x[chosen_locations[0][i]])
        
    plt.show()

# %%
def knn(layer,n, image, db):
    encoder_ = Model(auto_encoder.input,auto_encoder.layers[layer].output)
    pred = encoder_.predict(x)
    
    knn = NearestNeighbors(n_neighbors=n, metric="cosine")
    knn.fit(pred)
    _, ranks = knn.kneighbors(encoder_.predict(image.reshape((1,512,512,3))))
    return ranks

# %%
for i in x_t:
    ranks = knn(11, 5, i, x)
    plt.imshow(i)
    display(x,ranks)
# Out:
# 2022-03-14 03:08:34.753807: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-03-14 03:09:00.836070: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-03-14 03:09:22.477254: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-03-14 03:09:43.538089: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
my_cat = np.array(Image.open('my_cat.png').convert('RGB'))

# %%
my_cat.shape
# Out:
# (512, 512, 3)

# %%
cat_rank = knn(11, 5, my_cat, x)
plt.imshow(my_cat)
display(x,cat_rank)
# Out:
# 2022-03-14 03:10:05.244142: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 2022-03-14 03:10:25.119040: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
